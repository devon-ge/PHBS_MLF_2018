# %%
import matplotlib.pyplot as plt
import matplotlib.image as Mimage
from compress_func import compress_image

# %%
original = Mimage.imread('test.png')

# %%
compress_image('test.png')

# %%
pct40 = Mimage.imread('0.4_test.png')
pct50 = Mimage.imread('0.5_test.png')
pct60 = Mimage.imread('0.6_test.png')

# %%
Image('test.png')

# %%
Image('com_test.png')

# %%
Image('0.4_test.png')

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
plt.axis('off')
plt.title('Original image')
width,height,depth = original.shape
plt.imshow(original.reshape(width,height,depth))

plt.subplot(2,2,2)
plt.axis('off')
plt.title('compression ratio=0.4')
pct40 = Mimage.imread('0.4_test.png')
width,height,depth = pct40.shape
plt.imshow(pct40.reshape(width,height,depth))

plt.subplot(2,2,3)
plt.axis('off')
plt.title('compression ratio=0.5')
width,height,depth = pct50.shape
plt.imshow(pct50.reshape(width,height,depth))

plt.subplot(2,2,4)
plt.axis('off')
plt.title('compression ratio=0.6')
width,height,depth = pct60.shape
plt.imshow(pct60.reshape(width,height,depth))

# io.imsave('kmeans_32.png',kmeans_32)
plt.show()
